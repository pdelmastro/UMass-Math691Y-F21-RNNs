# %% [markdown]
# # Vanilla RNN, Country-Wide Daily Cases Data for Germany
#
# RNN from first notebook in this folder had problem of saturating during the second wave, which saw much larger numbers than the first wave. To attempt to avoid this issue, I'm trying out the non-saturating activation function ReLU.
#
# ## Task and RNN Model
#
# **Data**: Time-series for Germany from European Regional Tracker Dataset
# - Time series $\mathbf{y} = [\mathbf{y}(1), \mathbf{y}(2), ..., \mathbf{y}(T)]^t$
# - $\mathbf{y}(t) \in \mathbb{R}$ denotes  (normalized) number of new cases on $t$-th recorded day
#
# **Model**: *Non-Autonomous* Vanilla RNN
# - Equations:
# $$
# \mathbf{h}(t+1) = \textrm{ReLU} \big( \mathbf{W}_{hh} \mathbf{h}(t) + \mathbf{W}_{yh} \textrm{SW}_\tau[y](t) + \mathbf{b}_h\big)
# $$
# $$
# \mathbf{y}_{pred}(t) = \textrm{ReLU}\big(\mathbf{W}_{hy} \mathbf{h}(t) + b_y \big)
# $$
# - Trainable parameters:
#     - Input-hidden weights $\mathbf{W}_{yh}$, a $N_h \times \tau$ matrix
#     - Hidden-hidden weights $\mathbf{W}_{hh}$, a $N_h \times N_h$ matrix
#     - Hidden-output weights $\mathbf{W}_{hy}$, a $1 \times N_h$ matrix
#     - Hidden bias vector $\mathbf{b}_{h}$, a $N_h$-D Vector
#     - Output bias vector $b_{y}$, a scalar
#     - Initial Hidden State $\mathbf{h}(0)$, a $N_h$-D Vector
#
# **Optimization Goal**: Train RNN such that $\mathbf{y}_{pred}$ close to $\mathbf{y}$
#
# More specifically, we want to find $\mathbf{\Theta} = (\mathbf{W}_{hh}, \mathbf{W}_{yh}, \mathbf{W}_{hy}, \mathbf{b}_{h}, b_y, \mathbf{h}(0))$ that minimizes
#
# $$
# \textrm{RMSE}(\mathbf{y}, \mathbf{y}_{pred}) = \bigg[\frac{1}{T} \sum_{t=1}^T |\mathbf{y}(t) - \mathbf{y}_{pred}(t)|^2\bigg]^{1/2}
# $$

# %%
# Change root directory
import sys, os
sys.path.append(os.path.abspath('../../'))

# %%
# Package Imports
import torch
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits import mplot3d
from sklearn.decomposition import PCA

# MLP text size
import matplotlib
matplotlib.rc('font', size=16)

# %%
# Local Imports
from src.baseline_models import RNN
from src.load_data import ERT_germany
from src.train_and_eval import train
from src.clustering import hierarchical_clustering

# %% [markdown]
# ## Parameters

# %%
# Dataset parameters
dtype = 'cases_daily'
t0 = 200 # Timestep to start the sequence
T = 150 # Sequence length
tau_minus = 5 # Sliding window size for inputs
tau_plus  = 1 # Slide window for outputs. Currently un-used
country_wide_total = True

# Model parameters
N_h = 64
p_hh = 1
g_hh = 1
f_h = 'relu'
f_out = 'relu'
sigma = 0e-3 # noise parameter
tau = 2
learn_tau = False

# Training parameters
n_epochs = 4 * 256
lr = 5e-4
lr_decay = 0.75
weight_decay = 0.0
batches_til_first_lr_update=2 * 256
clip_gradient_thres=None
verbose = True

# %% [markdown]
# ## Setup

# %%
# Function to compute a sliding windows of the input time-series
def compute_SW(y, tau):
    """
    Given a tensor y of shape (T,), returns a new tensor SW
    of show (T,tau) where
    
                SW[t,k] =   0        if t-k < 0
                            y[t-k]   else
    """
    T = y.shape[0]
    SW = torch.zeros((T, tau))
    for i in range(tau):
        SW[(tau+1):,i] = y[:-(tau+1)]
    return SW

# %%
# Random Seed
seed = np.random.randint(1e6) # 349217
print('Random seed: %d' % seed)
np.random.seed(seed)

# Load the dataset
# directory where the data is stored, relative to this script
datadir = '../../euro_regional_tracker/germany_data/data'
# load the data from file
y_raw = ERT_germany(dtype=dtype, seq_len=T+t0, country_wide_total=country_wide_total,
    normalize=False, datadir=datadir
)[t0:]
# Save the sequence length
T = y_raw.shape[0]
# Create the input sequence (all zeros for now)
u = torch.zeros(1, T, 0)
# Reshape y_raw and save as the target y
y = y_raw.clone().view(1, T, 1)
y = y.view(1, T, 1)
# Normalize to -1,1
y -= y.min()
y /= 0.5 * y.max()
y -= 1

# Create the input sequence
SW = compute_SW(y.view(-1), tau_minus).view(1,-1,tau_minus)

# Create the RNN model
network = RNN(
    tau_minus, N_h, tau_plus,
    f_h=f_h, f_out=f_out, g_hh=g_hh, p_hh=p_hh,
    tau=tau, learn_tau=learn_tau
)
# Out:
# Random seed: 390390

# %%
# Plot of what the raw data looks like
plt.figure(figsize=(10,6))
plt.title('Germany: Daily Cases, Country-wide Total')
plt.xlabel('Time t (# days)')
plt.ylabel('# of new cases')
plt.plot(y_raw)
plt.show()

# %% [markdown]
# ## Training

# %%
losses, = train(network, SW, y, n_epochs, 1, lr, lr_decay=lr_decay,
        weight_decay=weight_decay,
        batches_til_first_lr_update=batches_til_first_lr_update,
        clip_gradient_thres=clip_gradient_thres, verbose=True
)
# Out:
#   Epoch 1/1024, Eval 1/1, Loss: 1.111
#   Epoch 2/1024, Eval 1/1, Loss: 1.019
#   Epoch 3/1024, Eval 1/1, Loss: 0.930
#   Epoch 4/1024, Eval 1/1, Loss: 0.843
#   Epoch 5/1024, Eval 1/1, Loss: 0.759
#   Epoch 6/1024, Eval 1/1, Loss: 0.681
#   Epoch 7/1024, Eval 1/1, Loss: 0.609
#   Epoch 8/1024, Eval 1/1, Loss: 0.542
#   Epoch 9/1024, Eval 1/1, Loss: 0.480
#   Epoch 10/1024, Eval 1/1, Loss: 0.421
#   Epoch 11/1024, Eval 1/1, Loss: 0.368
#   Epoch 12/1024, Eval 1/1, Loss: 0.323
#   Epoch 13/1024, Eval 1/1, Loss: 0.298
#   Epoch 14/1024, Eval 1/1, Loss: 0.292
#   Epoch 15/1024, Eval 1/1, Loss: 0.292
#   Epoch 16/1024, Eval 1/1, Loss: 0.291
#   Epoch 17/1024, Eval 1/1, Loss: 0.291
#   Epoch 18/1024, Eval 1/1, Loss: 0.290
#   Epoch 19/1024, Eval 1/1, Loss: 0.290
#   Epoch 20/1024, Eval 1/1, Loss: 0.290
#   Epoch 21/1024, Eval 1/1, Loss: 0.289
#   Epoch 22/1024, Eval 1/1, Loss: 0.289
#   Epoch 23/1024, Eval 1/1, Loss: 0.289
#   Epoch 130/1024, Eval 1/1, Loss: 0.252
#   Epoch 131/1024, Eval 1/1, Loss: 0.252
#   Epoch 132/1024, Eval 1/1, Loss: 0.252
#   Epoch 133/1024, Eval 1/1, Loss: 0.252
#   Epoch 134/1024, Eval 1/1, Loss: 0.252
#   Epoch 135/1024, Eval 1/1, Loss: 0.252
#   Epoch 136/1024, Eval 1/1, Loss: 0.251
#   Epoch 137/1024, Eval 1/1, Loss: 0.251
#   Epoch 138/1024, Eval 1/1, Loss: 0.251
#   Epoch 139/1024, Eval 1/1, Loss: 0.251
#   Epoch 140/1024, Eval 1/1, Loss: 0.251
#   Epoch 141/1024, Eval 1/1, Loss: 0.251
#   Epoch 142/1024, Eval 1/1, Loss: 0.251
#   Epoch 143/1024, Eval 1/1, Loss: 0.251
#   Epoch 144/1024, Eval 1/1, Loss: 0.251
#   Epoch 145/1024, Eval 1/1, Loss: 0.251
#   Epoch 146/1024, Eval 1/1, Loss: 0.251
#   Epoch 147/1024, Eval 1/1, Loss: 0.250
#   Epoch 148/1024, Eval 1/1, Loss: 0.250
#   Epoch 149/1024, Eval 1/1, Loss: 0.250
#   Epoch 150/1024, Eval 1/1, Loss: 0.250
#   Epoch 151/1024, Eval 1/1, Loss: 0.250
#   Epoch 152/1024, Eval 1/1, Loss: 0.250
#   Epoch 153/1024, Eval 1/1, Loss: 0.250
#   Epoch 154/1024, Eval 1/1, Loss: 0.250
#   Epoch 155/1024, Eval 1/1, Loss: 0.250
#   Epoch 156/1024, Eval 1/1, Loss: 0.250
#   Epoch 157/1024, Eval 1/1, Loss: 0.250
#   Epoch 158/1024, Eval 1/1, Loss: 0.250
#   Epoch 159/1024, Eval 1/1, Loss: 0.249
#   Epoch 160/1024, Eval 1/1, Loss: 0.249
#   Epoch 161/1024, Eval 1/1, Loss: 0.249
#   Epoch 162/1024, Eval 1/1, Loss: 0.249
#   Epoch 163/1024, Eval 1/1, Loss: 0.249
#   Epoch 164/1024, Eval 1/1, Loss: 0.249
#   Epoch 165/1024, Eval 1/1, Loss: 0.249
#   Epoch 166/1024, Eval 1/1, Loss: 0.249
#   Epoch 167/1024, Eval 1/1, Loss: 0.249
#   Epoch 168/1024, Eval 1/1, Loss: 0.249
#   Epoch 169/1024, Eval 1/1, Loss: 0.249
#   Epoch 170/1024, Eval 1/1, Loss: 0.249
#   Epoch 171/1024, Eval 1/1, Loss: 0.248
#   Epoch 172/1024, Eval 1/1, Loss: 0.248
#   Epoch 173/1024, Eval 1/1, Loss: 0.248
#   Epoch 174/1024, Eval 1/1, Loss: 0.248
#   Epoch 175/1024, Eval 1/1, Loss: 0.248
#   Epoch 176/1024, Eval 1/1, Loss: 0.248
#   Epoch 177/1024, Eval 1/1, Loss: 0.248
#   Epoch 178/1024, Eval 1/1, Loss: 0.248
#   Epoch 179/1024, Eval 1/1, Loss: 0.248
#   Epoch 180/1024, Eval 1/1, Loss: 0.248
#   Epoch 181/1024, Eval 1/1, Loss: 0.248
#   Epoch 182/1024, Eval 1/1, Loss: 0.248
#   Epoch 501/1024, Eval 1/1, Loss: 0.086
#   Epoch 502/1024, Eval 1/1, Loss: 0.086
#   Epoch 503/1024, Eval 1/1, Loss: 0.086
#   Epoch 504/1024, Eval 1/1, Loss: 0.086
#   Epoch 505/1024, Eval 1/1, Loss: 0.086
#   Epoch 506/1024, Eval 1/1, Loss: 0.086
#   Epoch 507/1024, Eval 1/1, Loss: 0.086
#   Epoch 508/1024, Eval 1/1, Loss: 0.086
#   Epoch 509/1024, Eval 1/1, Loss: 0.085
#   Epoch 510/1024, Eval 1/1, Loss: 0.085
#   Epoch 511/1024, Eval 1/1, Loss: 0.085
#   Epoch 512/1024, Eval 1/1, Loss: 0.085
#   Epoch 513/1024, Eval 1/1, Loss: 0.085
#   Epoch 514/1024, Eval 1/1, Loss: 0.085
#   Epoch 515/1024, Eval 1/1, Loss: 0.085
#   Epoch 516/1024, Eval 1/1, Loss: 0.085
#   Epoch 517/1024, Eval 1/1, Loss: 0.085
#   Epoch 518/1024, Eval 1/1, Loss: 0.085
#   Epoch 519/1024, Eval 1/1, Loss: 0.085
#   Epoch 520/1024, Eval 1/1, Loss: 0.085
#   Epoch 521/1024, Eval 1/1, Loss: 0.085
#   Epoch 522/1024, Eval 1/1, Loss: 0.084
#   Epoch 523/1024, Eval 1/1, Loss: 0.084
#   Epoch 524/1024, Eval 1/1, Loss: 0.084
#   Epoch 525/1024, Eval 1/1, Loss: 0.084
#   Epoch 526/1024, Eval 1/1, Loss: 0.084
#   Epoch 527/1024, Eval 1/1, Loss: 0.084
#   Epoch 528/1024, Eval 1/1, Loss: 0.084
#   Epoch 529/1024, Eval 1/1, Loss: 0.084
#   Epoch 530/1024, Eval 1/1, Loss: 0.084
#   Epoch 531/1024, Eval 1/1, Loss: 0.084
#   Epoch 532/1024, Eval 1/1, Loss: 0.084
#   Epoch 533/1024, Eval 1/1, Loss: 0.084
#   Epoch 534/1024, Eval 1/1, Loss: 0.084
#   Epoch 535/1024, Eval 1/1, Loss: 0.084
#   Epoch 536/1024, Eval 1/1, Loss: 0.084
#   Epoch 537/1024, Eval 1/1, Loss: 0.084
#   Epoch 538/1024, Eval 1/1, Loss: 0.084
#   Epoch 539/1024, Eval 1/1, Loss: 0.083
#   Epoch 540/1024, Eval 1/1, Loss: 0.083
#   Epoch 541/1024, Eval 1/1, Loss: 0.083
#   Epoch 542/1024, Eval 1/1, Loss: 0.083
#   Epoch 543/1024, Eval 1/1, Loss: 0.083
#   Epoch 544/1024, Eval 1/1, Loss: 0.083
#   Epoch 545/1024, Eval 1/1, Loss: 0.083
#   Epoch 546/1024, Eval 1/1, Loss: 0.083
#   Epoch 547/1024, Eval 1/1, Loss: 0.083
#   Epoch 548/1024, Eval 1/1, Loss: 0.083
#   Epoch 549/1024, Eval 1/1, Loss: 0.083
#   Epoch 550/1024, Eval 1/1, Loss: 0.083
#   Epoch 551/1024, Eval 1/1, Loss: 0.083
#   Epoch 552/1024, Eval 1/1, Loss: 0.083
#   Epoch 553/1024, Eval 1/1, Loss: 0.083
#   Epoch 554/1024, Eval 1/1, Loss: 0.083
#   Epoch 608/1024, Eval 1/1, Loss: 0.080
#   Epoch 609/1024, Eval 1/1, Loss: 0.080
#   Epoch 610/1024, Eval 1/1, Loss: 0.080
#   Epoch 611/1024, Eval 1/1, Loss: 0.080
#   Epoch 612/1024, Eval 1/1, Loss: 0.080
#   Epoch 613/1024, Eval 1/1, Loss: 0.080
#   Epoch 614/1024, Eval 1/1, Loss: 0.080
#   Epoch 615/1024, Eval 1/1, Loss: 0.080
#   Epoch 616/1024, Eval 1/1, Loss: 0.080
#   Epoch 617/1024, Eval 1/1, Loss: 0.080
#   Epoch 618/1024, Eval 1/1, Loss: 0.080
#   Epoch 619/1024, Eval 1/1, Loss: 0.079
#   Epoch 620/1024, Eval 1/1, Loss: 0.079
#   Epoch 621/1024, Eval 1/1, Loss: 0.079
#   Epoch 622/1024, Eval 1/1, Loss: 0.079
#   Epoch 623/1024, Eval 1/1, Loss: 0.079
#   Epoch 624/1024, Eval 1/1, Loss: 0.079
#   Epoch 625/1024, Eval 1/1, Loss: 0.079
#   Epoch 626/1024, Eval 1/1, Loss: 0.079
#   Epoch 627/1024, Eval 1/1, Loss: 0.079
#   Epoch 628/1024, Eval 1/1, Loss: 0.079
#   Epoch 629/1024, Eval 1/1, Loss: 0.079
#   Epoch 630/1024, Eval 1/1, Loss: 0.079
#   Epoch 631/1024, Eval 1/1, Loss: 0.079
#   Epoch 632/1024, Eval 1/1, Loss: 0.079
#   Epoch 633/1024, Eval 1/1, Loss: 0.079
#   Epoch 634/1024, Eval 1/1, Loss: 0.079
#   Epoch 635/1024, Eval 1/1, Loss: 0.079
#   Epoch 636/1024, Eval 1/1, Loss: 0.079
#   Epoch 637/1024, Eval 1/1, Loss: 0.079
#   Epoch 638/1024, Eval 1/1, Loss: 0.079
#   Epoch 639/1024, Eval 1/1, Loss: 0.079
#   Epoch 640/1024, Eval 1/1, Loss: 0.079
#   Epoch 641/1024, Eval 1/1, Loss: 0.079
#   Epoch 642/1024, Eval 1/1, Loss: 0.078
#   Epoch 643/1024, Eval 1/1, Loss: 0.078
#   Epoch 644/1024, Eval 1/1, Loss: 0.078
#   Epoch 645/1024, Eval 1/1, Loss: 0.078
#   Epoch 646/1024, Eval 1/1, Loss: 0.078
#   Epoch 647/1024, Eval 1/1, Loss: 0.078
#   Epoch 648/1024, Eval 1/1, Loss: 0.078
#   Epoch 649/1024, Eval 1/1, Loss: 0.078
#   Epoch 650/1024, Eval 1/1, Loss: 0.078
#   Epoch 651/1024, Eval 1/1, Loss: 0.078
#   Epoch 652/1024, Eval 1/1, Loss: 0.078
#   Epoch 653/1024, Eval 1/1, Loss: 0.078
#   Epoch 654/1024, Eval 1/1, Loss: 0.078
#   Epoch 655/1024, Eval 1/1, Loss: 0.078
#   Epoch 656/1024, Eval 1/1, Loss: 0.078
#   Epoch 657/1024, Eval 1/1, Loss: 0.078
#   Epoch 658/1024, Eval 1/1, Loss: 0.078
#   Epoch 659/1024, Eval 1/1, Loss: 0.078
#   Epoch 660/1024, Eval 1/1, Loss: 0.078
#   Epoch 714/1024, Eval 1/1, Loss: 0.076
#   Epoch 715/1024, Eval 1/1, Loss: 0.076
#   Epoch 716/1024, Eval 1/1, Loss: 0.076
#   Epoch 717/1024, Eval 1/1, Loss: 0.076
#   Epoch 718/1024, Eval 1/1, Loss: 0.076
#   Epoch 719/1024, Eval 1/1, Loss: 0.076
#   Epoch 720/1024, Eval 1/1, Loss: 0.076
#   Epoch 721/1024, Eval 1/1, Loss: 0.076
#   Epoch 722/1024, Eval 1/1, Loss: 0.076
#   Epoch 723/1024, Eval 1/1, Loss: 0.076
#   Epoch 724/1024, Eval 1/1, Loss: 0.076
#   Epoch 725/1024, Eval 1/1, Loss: 0.076
#   Epoch 726/1024, Eval 1/1, Loss: 0.076
#   Epoch 727/1024, Eval 1/1, Loss: 0.076
#   Epoch 728/1024, Eval 1/1, Loss: 0.076
#   Epoch 729/1024, Eval 1/1, Loss: 0.075
#   Epoch 730/1024, Eval 1/1, Loss: 0.075
#   Epoch 731/1024, Eval 1/1, Loss: 0.075
#   Epoch 732/1024, Eval 1/1, Loss: 0.075
#   Epoch 733/1024, Eval 1/1, Loss: 0.075
#   Epoch 734/1024, Eval 1/1, Loss: 0.075
#   Epoch 735/1024, Eval 1/1, Loss: 0.075
#   Epoch 736/1024, Eval 1/1, Loss: 0.075
#   Epoch 737/1024, Eval 1/1, Loss: 0.075
#   Epoch 738/1024, Eval 1/1, Loss: 0.075
#   Epoch 739/1024, Eval 1/1, Loss: 0.075
#   Epoch 740/1024, Eval 1/1, Loss: 0.075
#   Epoch 741/1024, Eval 1/1, Loss: 0.075
#   Epoch 742/1024, Eval 1/1, Loss: 0.075
#   Epoch 743/1024, Eval 1/1, Loss: 0.075
#   Epoch 744/1024, Eval 1/1, Loss: 0.075
#   Epoch 745/1024, Eval 1/1, Loss: 0.075
#   Epoch 746/1024, Eval 1/1, Loss: 0.075
#   Epoch 747/1024, Eval 1/1, Loss: 0.075
#   Epoch 748/1024, Eval 1/1, Loss: 0.075
#   Epoch 749/1024, Eval 1/1, Loss: 0.075
#   Epoch 750/1024, Eval 1/1, Loss: 0.075
#   Epoch 751/1024, Eval 1/1, Loss: 0.075
#   Epoch 752/1024, Eval 1/1, Loss: 0.075
#   Epoch 753/1024, Eval 1/1, Loss: 0.075
#   Epoch 754/1024, Eval 1/1, Loss: 0.075
#   Epoch 755/1024, Eval 1/1, Loss: 0.075
#   Epoch 756/1024, Eval 1/1, Loss: 0.075
#   Epoch 757/1024, Eval 1/1, Loss: 0.075
#   Epoch 758/1024, Eval 1/1, Loss: 0.075
#   Epoch 759/1024, Eval 1/1, Loss: 0.075
#   Epoch 760/1024, Eval 1/1, Loss: 0.075
#   Epoch 761/1024, Eval 1/1, Loss: 0.075
#   Epoch 762/1024, Eval 1/1, Loss: 0.075
#   Epoch 763/1024, Eval 1/1, Loss: 0.074
#   Epoch 764/1024, Eval 1/1, Loss: 0.074
#   Epoch 765/1024, Eval 1/1, Loss: 0.074
#   Epoch 766/1024, Eval 1/1, Loss: 0.074
#   Epoch 767/1024, Eval 1/1, Loss: 0.074
#   Epoch 768/1024, Eval 1/1, Loss: 0.074
#   Epoch 769/1024, Eval 1/1, Loss: 0.074
#   Epoch 770/1024, Eval 1/1, Loss: 0.074
#   Epoch 771/1024, Eval 1/1, Loss: 0.074
#   Epoch 772/1024, Eval 1/1, Loss: 0.074
#   Epoch 773/1024, Eval 1/1, Loss: 0.074
#   Epoch 774/1024, Eval 1/1, Loss: 0.074
#   Epoch 775/1024, Eval 1/1, Loss: 0.074
#   Epoch 776/1024, Eval 1/1, Loss: 0.074
#   Epoch 777/1024, Eval 1/1, Loss: 0.074
#   Epoch 778/1024, Eval 1/1, Loss: 0.074
#   Epoch 779/1024, Eval 1/1, Loss: 0.074
#   Epoch 780/1024, Eval 1/1, Loss: 0.074
#   Epoch 781/1024, Eval 1/1, Loss: 0.074
#   Epoch 782/1024, Eval 1/1, Loss: 0.074
#   Epoch 783/1024, Eval 1/1, Loss: 0.074
#   Epoch 784/1024, Eval 1/1, Loss: 0.074
#   Epoch 785/1024, Eval 1/1, Loss: 0.074
#   Epoch 786/1024, Eval 1/1, Loss: 0.074
#   Epoch 787/1024, Eval 1/1, Loss: 0.074
#   Epoch 788/1024, Eval 1/1, Loss: 0.074
#   Epoch 789/1024, Eval 1/1, Loss: 0.074
#   Epoch 790/1024, Eval 1/1, Loss: 0.074
#   Epoch 791/1024, Eval 1/1, Loss: 0.074
#   Epoch 792/1024, Eval 1/1, Loss: 0.074
#   Epoch 793/1024, Eval 1/1, Loss: 0.074
#   Epoch 794/1024, Eval 1/1, Loss: 0.074
#   Epoch 795/1024, Eval 1/1, Loss: 0.074
#   Epoch 796/1024, Eval 1/1, Loss: 0.074
#   Epoch 797/1024, Eval 1/1, Loss: 0.074
#   Epoch 798/1024, Eval 1/1, Loss: 0.074
#   Epoch 799/1024, Eval 1/1, Loss: 0.074
#   Epoch 800/1024, Eval 1/1, Loss: 0.074
#   Epoch 801/1024, Eval 1/1, Loss: 0.073
#   Epoch 802/1024, Eval 1/1, Loss: 0.073
#   Epoch 803/1024, Eval 1/1, Loss: 0.073
#   Epoch 804/1024, Eval 1/1, Loss: 0.073
#   Epoch 805/1024, Eval 1/1, Loss: 0.073
#   Epoch 806/1024, Eval 1/1, Loss: 0.073
#   Epoch 807/1024, Eval 1/1, Loss: 0.073
#   Epoch 808/1024, Eval 1/1, Loss: 0.073
#   Epoch 809/1024, Eval 1/1, Loss: 0.073
#   Epoch 810/1024, Eval 1/1, Loss: 0.073
#   Epoch 811/1024, Eval 1/1, Loss: 0.073
#   Epoch 812/1024, Eval 1/1, Loss: 0.073
#   Epoch 813/1024, Eval 1/1, Loss: 0.073
#   Epoch 814/1024, Eval 1/1, Loss: 0.073
#   Epoch 815/1024, Eval 1/1, Loss: 0.073
#   Epoch 816/1024, Eval 1/1, Loss: 0.073
#   Epoch 817/1024, Eval 1/1, Loss: 0.073
#   Epoch 818/1024, Eval 1/1, Loss: 0.073
#   Epoch 819/1024, Eval 1/1, Loss: 0.073
#   Epoch 873/1024, Eval 1/1, Loss: 0.072
#   Epoch 874/1024, Eval 1/1, Loss: 0.072
#   Epoch 875/1024, Eval 1/1, Loss: 0.072
#   Epoch 876/1024, Eval 1/1, Loss: 0.072
#   Epoch 877/1024, Eval 1/1, Loss: 0.072
#   Epoch 878/1024, Eval 1/1, Loss: 0.072
#   Epoch 879/1024, Eval 1/1, Loss: 0.072
#   Epoch 880/1024, Eval 1/1, Loss: 0.072
#   Epoch 881/1024, Eval 1/1, Loss: 0.072
#   Epoch 882/1024, Eval 1/1, Loss: 0.072
#   Epoch 883/1024, Eval 1/1, Loss: 0.072
#   Epoch 884/1024, Eval 1/1, Loss: 0.072
#   Epoch 885/1024, Eval 1/1, Loss: 0.072
#   Epoch 886/1024, Eval 1/1, Loss: 0.072
#   Epoch 887/1024, Eval 1/1, Loss: 0.072
#   Epoch 888/1024, Eval 1/1, Loss: 0.072
#   Epoch 889/1024, Eval 1/1, Loss: 0.073
#   Epoch 890/1024, Eval 1/1, Loss: 0.073
#   Epoch 891/1024, Eval 1/1, Loss: 0.072
#   Epoch 892/1024, Eval 1/1, Loss: 0.073
#   Epoch 893/1024, Eval 1/1, Loss: 0.072
#   Epoch 894/1024, Eval 1/1, Loss: 0.071
#   Epoch 895/1024, Eval 1/1, Loss: 0.072
#   Epoch 896/1024, Eval 1/1, Loss: 0.071
#   Epoch 897/1024, Eval 1/1, Loss: 0.072
#   Epoch 898/1024, Eval 1/1, Loss: 0.072
#   Epoch 899/1024, Eval 1/1, Loss: 0.071
#   Epoch 900/1024, Eval 1/1, Loss: 0.072
#   Epoch 901/1024, Eval 1/1, Loss: 0.072
#   Epoch 902/1024, Eval 1/1, Loss: 0.071
#   Epoch 903/1024, Eval 1/1, Loss: 0.073
#   Epoch 904/1024, Eval 1/1, Loss: 0.076
#   Epoch 905/1024, Eval 1/1, Loss: 0.074
#   Epoch 906/1024, Eval 1/1, Loss: 0.076
#   Epoch 907/1024, Eval 1/1, Loss: 0.072
#   Epoch 908/1024, Eval 1/1, Loss: 0.074
#   Epoch 909/1024, Eval 1/1, Loss: 0.071
#   Epoch 910/1024, Eval 1/1, Loss: 0.075
#   Epoch 911/1024, Eval 1/1, Loss: 0.073
#   Epoch 912/1024, Eval 1/1, Loss: 0.073
#   Epoch 913/1024, Eval 1/1, Loss: 0.072
#   Epoch 914/1024, Eval 1/1, Loss: 0.072
#   Epoch 915/1024, Eval 1/1, Loss: 0.073
#   Epoch 916/1024, Eval 1/1, Loss: 0.073
#   Epoch 917/1024, Eval 1/1, Loss: 0.072
#   Epoch 918/1024, Eval 1/1, Loss: 0.071
#   Epoch 919/1024, Eval 1/1, Loss: 0.072
#   Epoch 920/1024, Eval 1/1, Loss: 0.071
#   Epoch 921/1024, Eval 1/1, Loss: 0.071
#   Epoch 922/1024, Eval 1/1, Loss: 0.070
#   Epoch 923/1024, Eval 1/1, Loss: 0.071
#   Epoch 924/1024, Eval 1/1, Loss: 0.070
#   Epoch 925/1024, Eval 1/1, Loss: 0.070
#   Epoch 926/1024, Eval 1/1, Loss: 0.070
#   Epoch 927/1024, Eval 1/1, Loss: 0.070
#   Epoch 928/1024, Eval 1/1, Loss: 0.070
#   Epoch 929/1024, Eval 1/1, Loss: 0.070
#   Epoch 930/1024, Eval 1/1, Loss: 0.070
#   Epoch 931/1024, Eval 1/1, Loss: 0.070
#   Epoch 932/1024, Eval 1/1, Loss: 0.070
#   Epoch 933/1024, Eval 1/1, Loss: 0.070
#   Epoch 934/1024, Eval 1/1, Loss: 0.070
#   Epoch 935/1024, Eval 1/1, Loss: 0.070
#   Epoch 936/1024, Eval 1/1, Loss: 0.070
#   Epoch 937/1024, Eval 1/1, Loss: 0.070
#   Epoch 938/1024, Eval 1/1, Loss: 0.070
#   Epoch 939/1024, Eval 1/1, Loss: 0.070
#   Epoch 940/1024, Eval 1/1, Loss: 0.070
#   Epoch 941/1024, Eval 1/1, Loss: 0.070
#   Epoch 942/1024, Eval 1/1, Loss: 0.070
#   Epoch 943/1024, Eval 1/1, Loss: 0.070
#   Epoch 944/1024, Eval 1/1, Loss: 0.070
#   Epoch 945/1024, Eval 1/1, Loss: 0.070
#   Epoch 946/1024, Eval 1/1, Loss: 0.070
#   Epoch 947/1024, Eval 1/1, Loss: 0.070
#   Epoch 948/1024, Eval 1/1, Loss: 0.070
#   Epoch 949/1024, Eval 1/1, Loss: 0.070
#   Epoch 950/1024, Eval 1/1, Loss: 0.070
#   Epoch 951/1024, Eval 1/1, Loss: 0.069
#   Epoch 952/1024, Eval 1/1, Loss: 0.069
#   Epoch 953/1024, Eval 1/1, Loss: 0.069
#   Epoch 954/1024, Eval 1/1, Loss: 0.069
#   Epoch 955/1024, Eval 1/1, Loss: 0.069
#   Epoch 956/1024, Eval 1/1, Loss: 0.069
#   Epoch 957/1024, Eval 1/1, Loss: 0.069
#   Epoch 958/1024, Eval 1/1, Loss: 0.069
#   Epoch 959/1024, Eval 1/1, Loss: 0.069
#   Epoch 960/1024, Eval 1/1, Loss: 0.069
#   Epoch 961/1024, Eval 1/1, Loss: 0.069
#   Epoch 962/1024, Eval 1/1, Loss: 0.069
#   Epoch 963/1024, Eval 1/1, Loss: 0.069
#   Epoch 964/1024, Eval 1/1, Loss: 0.069
#   Epoch 965/1024, Eval 1/1, Loss: 0.069
#   Epoch 966/1024, Eval 1/1, Loss: 0.069
#   Epoch 967/1024, Eval 1/1, Loss: 0.069
#   Epoch 968/1024, Eval 1/1, Loss: 0.069
#   Epoch 969/1024, Eval 1/1, Loss: 0.069
#   Epoch 970/1024, Eval 1/1, Loss: 0.069
#   Epoch 971/1024, Eval 1/1, Loss: 0.069
#   Epoch 972/1024, Eval 1/1, Loss: 0.069
#   Epoch 973/1024, Eval 1/1, Loss: 0.069
#   Epoch 974/1024, Eval 1/1, Loss: 0.069
#   Epoch 975/1024, Eval 1/1, Loss: 0.069
#   Epoch 976/1024, Eval 1/1, Loss: 0.069
#   Epoch 977/1024, Eval 1/1, Loss: 0.069
#   Epoch 978/1024, Eval 1/1, Loss: 0.069
#   Epoch 979/1024, Eval 1/1, Loss: 0.069
#   Epoch 980/1024, Eval 1/1, Loss: 0.069
#   Epoch 981/1024, Eval 1/1, Loss: 0.069
#   Epoch 982/1024, Eval 1/1, Loss: 0.069
#   Epoch 983/1024, Eval 1/1, Loss: 0.069
#   Epoch 984/1024, Eval 1/1, Loss: 0.069
#   Epoch 985/1024, Eval 1/1, Loss: 0.069
#   Epoch 986/1024, Eval 1/1, Loss: 0.069
#   Epoch 987/1024, Eval 1/1, Loss: 0.069
#   Epoch 988/1024, Eval 1/1, Loss: 0.069
#   Epoch 989/1024, Eval 1/1, Loss: 0.069
#   Epoch 990/1024, Eval 1/1, Loss: 0.069
#   Epoch 991/1024, Eval 1/1, Loss: 0.069
#   Epoch 992/1024, Eval 1/1, Loss: 0.069
#   Epoch 993/1024, Eval 1/1, Loss: 0.069
#   Epoch 994/1024, Eval 1/1, Loss: 0.069
#   Epoch 995/1024, Eval 1/1, Loss: 0.069
#   Epoch 996/1024, Eval 1/1, Loss: 0.069
#   Epoch 997/1024, Eval 1/1, Loss: 0.069
#   Epoch 998/1024, Eval 1/1, Loss: 0.068
#   Epoch 999/1024, Eval 1/1, Loss: 0.068
#   Epoch 1000/1024, Eval 1/1, Loss: 0.068
#   Epoch 1001/1024, Eval 1/1, Loss: 0.068
#   Epoch 1002/1024, Eval 1/1, Loss: 0.068
#   Epoch 1003/1024, Eval 1/1, Loss: 0.068
#   Epoch 1004/1024, Eval 1/1, Loss: 0.068
#   Epoch 1005/1024, Eval 1/1, Loss: 0.068
#   Epoch 1006/1024, Eval 1/1, Loss: 0.068
#   Epoch 1007/1024, Eval 1/1, Loss: 0.068
#   Epoch 1008/1024, Eval 1/1, Loss: 0.068
#   Epoch 1009/1024, Eval 1/1, Loss: 0.068
#   Epoch 1010/1024, Eval 1/1, Loss: 0.068
#   Epoch 1011/1024, Eval 1/1, Loss: 0.068
#   Epoch 1012/1024, Eval 1/1, Loss: 0.068
#   Epoch 1013/1024, Eval 1/1, Loss: 0.068
#   Epoch 1014/1024, Eval 1/1, Loss: 0.068
#   Epoch 1015/1024, Eval 1/1, Loss: 0.068
#   Epoch 1016/1024, Eval 1/1, Loss: 0.068
#   Epoch 1017/1024, Eval 1/1, Loss: 0.068
#   Epoch 1018/1024, Eval 1/1, Loss: 0.068
#   Epoch 1019/1024, Eval 1/1, Loss: 0.068
#   Epoch 1020/1024, Eval 1/1, Loss: 0.068
#   Epoch 1021/1024, Eval 1/1, Loss: 0.068
#   Epoch 1022/1024, Eval 1/1, Loss: 0.068
#   Epoch 1023/1024, Eval 1/1, Loss: 0.068
#   Epoch 1024/1024, Eval 1/1, Loss: 0.068

# %%
# Rescale losses to be in # of cases
rescaled_RMSE = y_raw.max() * np.sqrt(losses)

# Plot the learning curve
plt.figure(figsize=(10,6))
plt.title('Learning Curve')
plt.xlabel('Training Time (# epochs)')
plt.ylabel(r'RMSE')
plt.plot(rescaled_RMSE)
plt.show()

# %% [markdown]
# ## Visualization

# %%
# Visualize predictions until user tells us otherwise
T_viz = 175 #int(4 * T)

# Target task for T=T_viz
y_viz = ERT_germany(dtype=dtype, seq_len=t0+T_viz, country_wide_total=country_wide_total,
    normalize=False, datadir=datadir
)[t0:]
# Normalize based on y_raw
y_viz_normalized = y_viz.clone()
y_viz_normalized /= 0.5 * y_raw.max()
y_viz_normalized -= 1
# Sliding window for input
SW_viz = compute_SW(y_viz_normalized, tau_minus).view(1,-1,tau_minus)


# Make a prediction
with torch.no_grad():
    hd, y_pred = network(SW_viz, return_dynamics=True)

# Reshape and normalize
H = hd.detach().numpy().reshape(-1, N_h)
# H = (H - np.mean(H, axis=0)) # / np.std(H, axis=0)


# Reshape y_pred
y_pred = y_pred.view(T_viz)

# Re-scale y_pred to be in units of # of cases
y_pred = (1 + y_pred) * y_raw.max() * 0.5

# %%
"""
Visualize predictions
"""
plt.figure(figsize=(12,8))
plt.title('Network Predictions')
plt.xlabel('Time t (# timesteps)')
plt.ylabel('Output amplitude')
plt.xlim(0,T_viz-1)
# Plot output target
plt.fill_between(
    np.arange(T_viz), y_viz,
    step='mid', alpha=0.5,
    label='target'
)
# Plot network prediction
plt.plot(
    np.arange(T_viz), y_pred,
    ds='steps-mid', c='k', linewidth=3,
    label='predicted'
)
plt.legend(loc='center right')
# Add a line to indicate data the network saw during training
plt.plot([T,T],[y_viz.min(), y_viz.max()], 'r', linewidth=3)
plt.text(T + 1, y_viz.max() * 0.75, 'unobserved\nduring\ntraining')
plt.show()

# %%
"""
Dynamics heatmap
"""

# Reshape and normalize
H = hd.detach().numpy().reshape(-1, N_h)
H_centered = (H - np.mean(H, axis=0)) # / np.std(H, axis=0)

# Clustering
order = hierarchical_clustering(H_centered)

# Reorder dynamics heatmap
h_viz = np.zeros_like(H.T)
# Reorder columns of h
for j in range(N_h):
    h_viz[j] = H[:,order[j]]

plt.figure(figsize=(12,8))
plt.title('Hidden layer dynamics')
plt.xlabel('Time t (# timesteps)')
plt.ylabel('hidden unit #')
vmxx = np.max(np.abs(h_viz))
im = plt.imshow(h_viz, aspect='auto', interpolation='none', cmap='bwr_r'
)
divider = make_axes_locatable(plt.gca())
cax = divider.append_axes("right", size="2%", pad=0.05)
plt.colorbar(im, cax=cax)
plt.show()

# %%
"""
PCA of Dynamics
"""

fig, ax = plt.subplots(1,1,figsize=(8,8))
fig.suptitle('Low-dimensional visualization of dynamics')

# Subplot 1: PCA
pca = PCA(n_components=5)
H_pca = pca.fit_transform(h_viz.T)

PCA_inds = [0,1]
ax.set_xlabel('PCA %d' % PCA_inds[0])
ax.set_ylabel('PCA %d' % PCA_inds[1])
ax.scatter(
    H_pca[:, PCA_inds[0]],
    H_pca[:, PCA_inds[1]],
    c=np.arange(T_viz)/T_viz
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Potential Ideas
#
# - Transfer learning (idea from Carl)
#   - Train on data from the flu
#   - See if this known is sufficient to see how covid evolves
# - Train up to first half of second wave, so how well RNN does testing on second half of second wave
# - Use smaller RNN to see how few params we need to get good output
# - Also, actually get the RNN input
