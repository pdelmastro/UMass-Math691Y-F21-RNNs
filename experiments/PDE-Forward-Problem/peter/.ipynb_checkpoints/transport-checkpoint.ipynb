# %% [markdown]
# Using PINNs to solve the transport equation with periodic boundary conditions

# %% [markdown]
# ## **Setup**

# %%
# Set matplotlib for inline plots
# %matplotlib inline
# Set matplotlib default font size\n",
import matplotlib as mpl
mpl.rc('font', size=15)

# Library Imports
import os
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

# Local Imports
from src.models import FCNN
from src.pde import f_pde_transport, f_ic_basic_transport, u_exact_transport
from src.train import MeshBasedOptimizer, MeshFreeOptimizer
from src.mesh import visualize_predictions

# %% [markdown]
# ## **Mesh Based Training Experiment**

# %%
"""
Parameters
"""

# Network parameters
N_h = [128,128]

# Training parameters
nt = 50
nx = 20
alpha = np.array([1,1.5,1])       # Relative importance of pde / bc / ic loss
n_iters = 2000     # Number of training iterations
lr = 1e-3          # Learning rate
verbose=100

# Visualization parameters (during training)
make_pred_figs = None # 15
fig_dir='./figures/transport'
fig_fname='transport'
fig_mesh_size=(50,50)

"""
Setup
"""
# Set the random seed for reproducibility
seed = np.random.randint(1e6) # 913988
print('Random seed:', seed)
torch.manual_seed(seed)

# Create the network
network = FCNN(N_h=N_h)

# Create the optimizer
optimizer = MeshBasedOptimizer(nt, nx)

# Clear the figure directory
if make_pred_figs is not None:
    for f in os.listdir(fig_dir):
        if f.startswith(fig_fname):
            os.remove(os.path.join(fig_dir, f))

"""
Training Loop
"""
L_pde, L_bc, L_ic, L_train, L2_err = optimizer.train(network,
        f_pde_transport, f_ic_basic_transport, alpha=alpha, 
        n_iters=n_iters, lr=lr, verbose=verbose, f_u_exact=u_exact_transport,
        #make_pred_figs, fig_dir, fig_fname, fig_mesh_size
    )

# %%
"""
Plot the learning curves
"""
plt.figure(figsize=(10,6))
plt.title('Learning curves (LCs)')
plt.xlabel('Training time (# parameter updates)')
plt.ylabel('log LC')

LCs = [L_pde, L_bc, L_ic, L_train, L2_err]
labels = ['PDE', 'BC', 'IC', 'Train', 'L2 Error']
sample_rate = 1
times = sample_rate * np.arange(LCs[0].shape[0] / sample_rate)
for lc,label in zip(LCs, labels):
    plt.scatter(times, np.log(lc[::sample_rate]), label=label, s=5)
plt.legend()
# plt.savefig('%s/learning_curves.png' % fig_dir)
plt.show()

# %%
"""
Post training visualization
"""
fig, axs = visualize_predictions(
    network, u_exact_transport, n_t=50, n_x=50, T=1,
    suptitle='Post Training Predictions and Residuals'
)
plt.show()

# %%
fig, axs = visualize_predictions(
    network, u_exact_transport, n_t=50, n_x=50, T=1,
    suptitle='Post Training Predictions and Residuals',
    plot_types = ['pred', 'pde_res', 'res'],
    f_pde = f_pde_transport
)
plt.show()

# %%
"""
Number of parameters in the model
"""
num_params = 0
for param in network.parameters():
    num_params += param.numel()
print('# parameters:', num_params)

# %% [markdown]
# ## **Mesh Free Training Algorithm**

# %%
"""
Parameters
"""

# Network parameters
N_h = [64,64]

# Training parameters
n_pde_pts = 100   # Number of training points for pde / bc / ic
n_bc_pts = 20
n_ic_pts = 10    
alpha = np.array([1,1,5])       # Relative importance of pde / bc / ic loss
n_iters = 1200     # Number of training iterations
lr = 5e-3          # Learning rate
verbose=n_iters//15

# Visualization parameters (during training)
make_pred_figs = None # 15
fig_dir='./figures/transport'
fig_fname='transport'
fig_mesh_size=(50,50)

"""
Setup
"""
# Set the random seed for reproducibility
seed = np.random.randint(1e6) # 913988
print('Random seed:', seed)
torch.manual_seed(seed)

# Create the network
network = FCNN(N_h=N_h)

# Create the optimizer
optimizer = MeshFreeOptimizer(n_pde_pts, n_bc_pts, n_ic_pts)

# Clear the figure directory
if make_pred_figs is not None:
    for f in os.listdir(fig_dir):
        if f.startswith(fig_fname):
            os.remove(os.path.join(fig_dir, f))

"""
Training Loop
"""
L_pde, L_bc, L_ic, L_train, L2_err = optimizer.train(network,
        f_pde_transport, f_ic_basic_transport, alpha=alpha, 
        n_iters=n_iters, lr=lr, verbose=verbose, f_u_exact=u_exact_transport,
        #make_pred_figs, fig_dir, fig_fname, fig_mesh_size
    )
# Out:
# Random seed: 188016
# Iter 1/1200, Losses: PDE=8.53e-02  BC=1.90e-02  IC=4.42e-01  TR=2.31e+00 L2-err: 1.25e+00
# Iter 80/1200, Losses: PDE=1.99e-04  BC=4.07e-03  IC=2.94e-01  TR=1.47e+00 L2-err: 1.24e+00
# Iter 160/1200, Losses: PDE=1.60e-03  BC=2.24e-04  IC=4.44e-01  TR=2.22e+00 L2-err: 1.27e+00
# Iter 240/1200, Losses: PDE=1.36e-02  BC=2.00e-02  IC=3.98e-01  TR=2.02e+00 L2-err: 1.21e+00
# Iter 320/1200, Losses: PDE=2.83e-02  BC=2.98e-01  IC=6.86e-02  TR=6.70e-01 L2-err: 8.42e-01
# Iter 400/1200, Losses: PDE=7.36e-02  BC=1.24e-01  IC=2.73e-02  TR=3.34e-01 L2-err: 7.65e-01
# Iter 480/1200, Losses: PDE=8.52e-02  BC=1.66e-01  IC=2.56e-02  TR=3.80e-01 L2-err: 7.01e-01
# Iter 560/1200, Losses: PDE=8.84e-02  BC=1.48e-01  IC=8.78e-03  TR=2.80e-01 L2-err: 6.65e-01
# Iter 640/1200, Losses: PDE=6.51e-02  BC=1.05e-01  IC=5.28e-03  TR=1.96e-01 L2-err: 5.99e-01
# Iter 720/1200, Losses: PDE=3.48e-02  BC=4.31e-02  IC=6.16e-03  TR=1.09e-01 L2-err: 4.95e-01
# Iter 800/1200, Losses: PDE=2.45e-02  BC=3.83e-02  IC=8.38e-04  TR=6.70e-02 L2-err: 3.16e-01
# Iter 880/1200, Losses: PDE=5.95e-03  BC=9.09e-03  IC=1.06e-03  TR=2.03e-02 L2-err: 1.66e-01
# Iter 960/1200, Losses: PDE=3.48e-03  BC=1.86e-03  IC=3.37e-04  TR=7.03e-03 L2-err: 8.36e-02
# Iter 1040/1200, Losses: PDE=1.49e-03  BC=1.66e-03  IC=2.93e-04  TR=4.61e-03 L2-err: 5.33e-02
# Iter 1120/1200, Losses: PDE=1.15e-03  BC=7.22e-04  IC=6.07e-04  TR=4.91e-03 L2-err: 4.30e-02
# Iter 1200/1200, Losses: PDE=8.92e-04  BC=1.45e-03  IC=1.89e-04  TR=3.28e-03 L2-err: 4.30e-02

# %%
"""
Plot the learning curves
"""
plt.figure(figsize=(10,6))
plt.title('Learning curves (LCs)')
plt.xlabel('Training time (# parameter updates)')
plt.ylabel('log LC')

LCs = [L_pde, L_bc, L_ic, L_train, L2_err]
labels = ['PDE', 'BC', 'IC', 'Train', 'L2 Error']
sample_rate = 1
times = sample_rate * np.arange(LCs[0].shape[0] / sample_rate)
for lc,label in zip(LCs, labels):
    plt.scatter(times, np.log(lc[::sample_rate]), label=label, s=5)
plt.legend()
# plt.savefig('%s/learning_curves.png' % fig_dir)
plt.show()

# %%
"""
Post training visualization
"""
fig, axs = visualize_predictions(
    network, u_exact_transport, n_t=50, n_x=50, T=1,
    suptitle='Post Training Predictions and Residuals'
)
plt.show()
