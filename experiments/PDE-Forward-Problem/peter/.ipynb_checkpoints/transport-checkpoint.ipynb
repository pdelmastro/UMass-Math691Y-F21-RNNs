# %% [markdown]
# Using PINNs to solve the transport equation with periodic boundary conditions

# %% [markdown]
# ## **Setup**

# %%
# Set matplotlib for inline plots
# %matplotlib inline
# Set matplotlib default font size\n",
import matplotlib as mpl
mpl.rc('font', size=15)

# Library Imports
import os
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

# Local Imports
from src.models import FCNN
from src.pde import f_pde_transport, f_ic_basic_transport, u_exact_transport
from src.train import MeshBasedOptimizer, MeshFreeOptimizer
from src.mesh import visualize_predictions

# %% [markdown]
# ## **Mesh Based Training Experiment**

# %%
"""
Parameters
"""

# Network parameters
N_h = [128,128]

# Training parameters
nt = 50
nx = 20
alpha = np.array([1,1.5,1])       # Relative importance of pde / bc / ic loss
n_iters = 2000     # Number of training iterations
lr = 1e-3          # Learning rate
verbose=100

# Visualization parameters (during training)
make_pred_figs = None # 15
fig_dir='./figures/transport'
fig_fname='transport'
fig_mesh_size=(50,50)

"""
Setup
"""
# Set the random seed for reproducibility
seed = np.random.randint(1e6) # 913988
print('Random seed:', seed)
torch.manual_seed(seed)

# Create the network
network = FCNN(N_h=N_h)

# Create the optimizer
optimizer = MeshBasedOptimizer(nt, nx)

# Clear the figure directory
if make_pred_figs is not None:
    for f in os.listdir(fig_dir):
        if f.startswith(fig_fname):
            os.remove(os.path.join(fig_dir, f))

"""
Training Loop
"""
L_pde, L_bc, L_ic, L_train, L2_err = optimizer.train(network,
        f_pde_transport, f_ic_basic_transport, alpha=alpha, 
        n_iters=n_iters, lr=lr, verbose=verbose, f_u_exact=u_exact_transport,
        #make_pred_figs, fig_dir, fig_fname, fig_mesh_size
    )

# %%
"""
Plot the learning curves
"""
plt.figure(figsize=(10,6))
plt.title('Learning curves (LCs)')
plt.xlabel('Training time (# parameter updates)')
plt.ylabel('log LC')

LCs = [L_pde, L_bc, L_ic, L_train, L2_err]
labels = ['PDE', 'BC', 'IC', 'Train', 'L2 Error']
sample_rate = 1
times = sample_rate * np.arange(LCs[0].shape[0] / sample_rate)
for lc,label in zip(LCs, labels):
    plt.scatter(times, np.log(lc[::sample_rate]), label=label, s=5)
plt.legend()
# plt.savefig('%s/learning_curves.png' % fig_dir)
plt.show()

# %%
"""
Post training visualization
"""
fig, axs = visualize_predictions(
    network, u_exact_transport, n_t=50, n_x=50, T=1,
    suptitle='Post Training Predictions and Residuals'
)
plt.show()

# %%
fig, axs = visualize_predictions(
    network, u_exact_transport, n_t=50, n_x=50, T=1,
    suptitle='Post Training Predictions and Residuals',
    plot_types = ['pred', 'pde_res', 'res'],
    f_pde = f_pde_transport
)
plt.show()

# %%
"""
Number of parameters in the model
"""
num_params = 0
for param in network.parameters():
    num_params += param.numel()
print('# parameters:', num_params)

# %%
"""
Evaluation on finer mesh sizes
TODO: implement
"""

# %% [markdown]
# ## **Mesh Free Training Algorithm**

# %%
from scipy.stats import vonmises

def f_ic_von_Mises(v, kappa=4):
    """
    von-Mises distribution on the spatial domain [0,1]
    Only works for d = 1

    s[i] = t[i], x[i]
    """
    if len(v.shape) > 1:
        x = v[:,1:]
    else:
        x = v
    u_t = vonmises.pdf((2*x-1)*torch.pi, kappa)
    return torch.from_numpy(u_t)

# %%
"""
Parameters
"""

# Network parameters
N_h = [64,64]

# IC parameters
kappa = 4

# Training parameters
n_pde_pts = 100   # Number of training points for pde / bc / ic
n_bc_pts = 20
n_ic_pts = 10    
error_based = True
p_exploit = 0.90
alpha = np.array([1,1,2])       # Relative importance of pde / bc / ic loss
n_iters = 5000     # Number of training iterations
lr = 2e-3          # Learning rate
verbose=n_iters//20

# Visualization parameters (during training)
make_pred_figs = None # 15
fig_dir='./figures/transport'
fig_fname='transport'
fig_mesh_size=(50,50)

"""
Setup
"""
# Set the random seed for reproducibility
seed = np.random.randint(1e6) # 913988
print('Random seed:', seed)
torch.manual_seed(seed)

# Create the network
network = FCNN(N_h=N_h)

# Create the optimizer
optimizer = MeshFreeOptimizer(
    n_pde_pts, n_bc_pts, n_ic_pts, 
    error_based=error_based, p_exploit=p_exploit
)

# Clear the figure directory
if make_pred_figs is not None:
    for f in os.listdir(fig_dir):
        if f.startswith(fig_fname):
            os.remove(os.path.join(fig_dir, f))

# Functions definition the initial condition and exact solution
# f_ic = f_ic_basic_transport
# f_u_exact = u_exact_transport
f_ic = lambda v: f_ic_von_Mises(v, kappa)
f_u_exact = lambda v: u_exact_transport(v, f=f_ic)
            
"""
Training Loop
"""
L_pde, L_bc, L_ic, L_train, L2_err = optimizer.train(network,
        f_pde_transport, f_ic, 
        alpha=alpha, n_iters=n_iters, lr=lr, verbose=verbose, 
        f_u_exact=f_u_exact,
        #make_pred_figs, fig_dir, fig_fname, fig_mesh_size
    )
# Out:
# Random seed: 179218
# Iter 1/5000, Losses: PDE=1.87e-02  BC=1.69e-02  IC=2.67e-01  TR=5.70e-01 L2-err: 8.48e-01
# Iter 250/5000, Losses: PDE=1.40e-03  BC=2.05e-04  IC=5.69e-02  TR=1.15e-01 L2-err: 4.89e-01
# Iter 500/5000, Losses: PDE=3.11e-03  BC=3.73e-03  IC=1.13e-01  TR=2.33e-01 L2-err: 5.04e-01
# Iter 750/5000, Losses: PDE=5.46e-03  BC=8.81e-04  IC=1.02e-01  TR=2.11e-01 L2-err: 4.51e-01
# Iter 1000/5000, Losses: PDE=3.66e-03  BC=7.00e-03  IC=9.70e-02  TR=2.05e-01 L2-err: 4.69e-01
# Iter 1250/5000, Losses: PDE=6.60e-03  BC=1.97e-02  IC=6.52e-02  TR=1.57e-01 L2-err: 3.29e-01
# Iter 1500/5000, Losses: PDE=1.89e-02  BC=2.08e-02  IC=2.01e-02  TR=8.01e-02 L2-err: 3.03e-01
# Iter 1750/5000, Losses: PDE=1.69e-02  BC=3.83e-02  IC=1.86e-02  TR=9.23e-02 L2-err: 3.19e-01
# Iter 2000/5000, Losses: PDE=4.22e-03  BC=4.53e-02  IC=1.02e-02  TR=6.99e-02 L2-err: 2.74e-01
# Iter 2250/5000, Losses: PDE=1.59e-02  BC=3.59e-02  IC=1.67e-02  TR=8.52e-02 L2-err: 3.14e-01
# Iter 2500/5000, Losses: PDE=1.37e-02  BC=3.65e-02  IC=1.39e-02  TR=7.80e-02 L2-err: 3.47e-01
# Iter 2750/5000, Losses: PDE=1.58e-02  BC=2.03e-02  IC=1.07e-02  TR=5.76e-02 L2-err: 2.73e-01
# Iter 3000/5000, Losses: PDE=9.66e-03  BC=4.38e-02  IC=8.35e-03  TR=7.01e-02 L2-err: 2.59e-01
# Iter 3250/5000, Losses: PDE=1.24e-02  BC=2.76e-02  IC=8.50e-03  TR=5.70e-02 L2-err: 2.24e-01
# Iter 3500/5000, Losses: PDE=3.90e-03  BC=1.79e-02  IC=6.39e-03  TR=3.46e-02 L2-err: 2.11e-01
# Iter 3750/5000, Losses: PDE=1.81e-03  BC=4.84e-03  IC=4.22e-03  TR=1.51e-02 L2-err: 9.66e-02
# Iter 4000/5000, Losses: PDE=1.08e-03  BC=1.41e-03  IC=7.62e-04  TR=4.01e-03 L2-err: 5.32e-02
# Iter 4250/5000, Losses: PDE=8.17e-04  BC=3.93e-04  IC=2.39e-04  TR=1.69e-03 L2-err: 3.01e-02
# Iter 4500/5000, Losses: PDE=4.63e-04  BC=2.24e-04  IC=2.00e-05  TR=7.27e-04 L2-err: 2.61e-02
# Iter 4750/5000, Losses: PDE=3.12e-04  BC=6.47e-05  IC=9.50e-05  TR=5.67e-04 L2-err: 1.75e-02
# Iter 5000/5000, Losses: PDE=1.74e-04  BC=1.60e-04  IC=9.15e-05  TR=5.17e-04 L2-err: 1.93e-02

# %%
"""
Plot the learning curves
"""
plt.figure(figsize=(10,6))
plt.title('Learning curves (LCs)')
plt.xlabel('Training time (# parameter updates)')
plt.ylabel('log LC')

LCs = [L_pde, L_bc, L_ic, L_train, L2_err]
labels = ['PDE', 'BC', 'IC', 'Train', 'L2 Error']
sample_rate = 1
times = sample_rate * np.arange(LCs[0].shape[0] / sample_rate)
for lc,label in zip(LCs, labels):
    plt.scatter(times, np.log(lc[::sample_rate]), label=label, s=5)
plt.legend()
# plt.savefig('%s/learning_curves.png' % fig_dir)
plt.show()

# %%
"""
Post training visualization
"""
fig, axs = visualize_predictions(
    network, f_u_exact, n_t=50, n_x=50, T=1,
    suptitle='Post Training Predictions and Residuals'
)
plt.show()

# %%
fig, axs = visualize_predictions(
    network, f_u_exact, n_t=50, n_x=50, T=1,
    suptitle='Post Training Predictions and Residuals',
    plot_types = ['pred', 'pde_res', 'res'],
    f_pde = f_pde_transport
)
plt.show()
